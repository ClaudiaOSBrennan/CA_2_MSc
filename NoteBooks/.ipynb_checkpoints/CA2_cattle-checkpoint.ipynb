# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/fisheries_cattle_ok.csv")

# %%
df.head(3)
# Out:
#    YEAR LOCATION CATTLE_BREED_TYPE CATTLE_GENDER  CATTLE_AGE_0_6  \
# 0  2014    Boyne              BEEF             C               0
# 1  2020  Doonbeg              BEEF             C               0
# 2  2019     Ilen              BEEF             C               0
#
#    CATTLE_AGE_6_6  CATTLE_AGE_6_12  CATTLE_AGE_12_18  CATTLE_AGE_18_24  \
# 0               0                0                 3               199
# 1               0                0                 0                11
# 2               0                0                 0                12
#
#    CATTLE_AGE_24_30  CATTLE_AGE_30_36  CATTLE_AGE_36_PLUS
# 0               504              3929               57144
# 1                41               312                5863
# 2                78               473                6794

# %%
df.dtypes
# Out:
# YEAR                   int64
# LOCATION              object
# CATTLE_BREED_TYPE     object
# CATTLE_GENDER         object
# CATTLE_AGE_0_6         int64
# CATTLE_AGE_6_6         int64
# CATTLE_AGE_6_12        int64
# CATTLE_AGE_12_18       int64
# CATTLE_AGE_18_24       int64
# CATTLE_AGE_24_30       int64
# CATTLE_AGE_30_36       int64
# CATTLE_AGE_36_PLUS     int64
# dtype: object

# %%
df.isna().sum()
# Out:
# YEAR                  0
# LOCATION              0
# CATTLE_BREED_TYPE     0
# CATTLE_GENDER         0
# CATTLE_AGE_0_6        0
# CATTLE_AGE_6_6        0
# CATTLE_AGE_6_12       0
# CATTLE_AGE_12_18      0
# CATTLE_AGE_18_24      0
# CATTLE_AGE_24_30      0
# CATTLE_AGE_30_36      0
# CATTLE_AGE_36_PLUS    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['YEAR', 'LOCATION', 'CATTLE_BREED_TYPE', 'CATTLE_GENDER',
#        'CATTLE_AGE_0_6', 'CATTLE_AGE_6_6', 'CATTLE_AGE_6_12',
#        'CATTLE_AGE_12_18', 'CATTLE_AGE_18_24', 'CATTLE_AGE_24_30',
#        'CATTLE_AGE_30_36', 'CATTLE_AGE_36_PLUS'],
#       dtype='object')

# %%
df["YEAR"].value_counts()
# Out:
# 2020    504
# 2014    501
# 2019    501
# 2018    500
# 2017    499
# 2015    499
# 2016    499
# Name: YEAR, dtype: int64

# %%
df["LOCATION"].value_counts()
# Out:
# Boyne        294
# Doonbeg      294
# Ilen         294
# Dargle       294
# Inny         294
# Nore         294
# Moy          294
# Vartry       294
# Dodder       294
# Currane      294
# Gweebarra    293
# Erriff       270
# Name: LOCATION, dtype: int64

# %%
df["CATTLE_BREED_TYPE"].value_counts()
# Out:
# BEEF     1764
# DAIRY    1739
# Name: CATTLE_BREED_TYPE, dtype: int64

# %%
df["CATTLE_GENDER"].value_counts()
# Out:
# C    1176
# M    1164
# F    1163
# Name: CATTLE_GENDER, dtype: int64

# %%
df.describe()
# Out:
#               YEAR  CATTLE_AGE_0_6  CATTLE_AGE_6_6  CATTLE_AGE_6_12  \
# count  3503.000000     3503.000000     3503.000000      3503.000000
# mean   2017.003997      199.013703      879.411647      4861.249215
# std       2.002564      419.229429     1960.876775     10349.550723
# min    2014.000000        0.000000        0.000000         0.000000
# 25%    2015.000000        0.000000        0.000000         0.000000
# 50%    2017.000000        6.000000       39.000000       190.000000
# 75%    2019.000000      135.500000      360.500000      2701.000000
# max    2020.000000     1899.000000     8806.000000     47728.000000
#
#        CATTLE_AGE_12_18  CATTLE_AGE_18_24  CATTLE_AGE_24_30  CATTLE_AGE_30_36  \
# count       3503.000000       3503.000000       3503.000000       3503.000000
# mean        1055.110191       4329.667713        573.125036       1488.315729
# std         2513.425008       9668.027380       1201.619899       3123.442653
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000         12.000000          9.000000         27.000000
# 50%           26.000000        133.000000         65.000000        160.000000
# 75%          408.000000       1780.000000        376.500000       1618.500000
# max        12260.000000      45338.000000       7203.000000      24984.000000
#
#        CATTLE_AGE_36_PLUS
# count         3503.000000
# mean          5833.965173
# std          16059.156178
# min              0.000000
# 25%             24.000000
# 50%            222.000000
# 75%           1281.000000
# max         106374.000000

# %%
plt.figure(figsize=(10,5))
ax = sns.displot(data=df, x="CATTLE_AGE_0_6")

# %%
sns.displot(data=df, x="CATTLE_AGE_6_6")

# %%
sns.displot(data=df, x="CATTLE_AGE_6_12")

# %%
sns.displot(data=df, x="CATTLE_AGE_12_18")

# %%
sns.displot(data=df, x="CATTLE_AGE_18_24")

# %%
sns.displot(data=df, x="CATTLE_AGE_18_24")

# %%
sns.displot(data=df, x="CATTLE_AGE_24_30")

# %%
sns.displot(data=df, x="CATTLE_AGE_30_36")

# %%
df.groupby("YEAR").sum().plot()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
for column in df.groupby("YEAR").sum():
    df.groupby("YEAR").sum()[column].plot()
    plt.show()

# %%
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df, x="CATTLE_AGE_0_6", y="CATTLE_AGE_6_6")
# Out:
# <AxesSubplot:xlabel='CATTLE_AGE_0_6', ylabel='CATTLE_AGE_6_6'>

# %%
sns.scatterplot(data=df, x="CATTLE_AGE_0_6", y="CATTLE_AGE_30_36")
# Out:
# <AxesSubplot:xlabel='CATTLE_AGE_0_6', ylabel='CATTLE_AGE_30_36'>

# %%
sns.scatterplot(data=df, x="CATTLE_AGE_0_6", y="CATTLE_AGE_36_PLUS")
# Out:
# <AxesSubplot:xlabel='CATTLE_AGE_0_6', ylabel='CATTLE_AGE_36_PLUS'>

# %%
sns.scatterplot(data=df, x="CATTLE_AGE_30_36", y="CATTLE_AGE_36_PLUS")
# Out:
# <AxesSubplot:xlabel='CATTLE_AGE_30_36', ylabel='CATTLE_AGE_36_PLUS'>

# %%
df.head(3)
# Out:
#    YEAR LOCATION CATTLE_BREED_TYPE CATTLE_GENDER  CATTLE_AGE_0_6  \
# 0  2014    Boyne              BEEF             C               0
# 1  2020  Doonbeg              BEEF             C               0
# 2  2019     Ilen              BEEF             C               0
#
#    CATTLE_AGE_6_6  CATTLE_AGE_6_12  CATTLE_AGE_12_18  CATTLE_AGE_18_24  \
# 0               0                0                 3               199
# 1               0                0                 0                11
# 2               0                0                 0                12
#
#    CATTLE_AGE_24_30  CATTLE_AGE_30_36  CATTLE_AGE_36_PLUS
# 0               504              3929               57144
# 1                41               312                5863
# 2                78               473                6794

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=1)
pca.fit(df.drop(columns=["YEAR","LOCATION","CATTLE_BREED_TYPE",
                    "CATTLE_GENDER","CATTLE_AGE_30_36",
                    "CATTLE_AGE_36_PLUS"]).dropna())
print(pca.explained_variance_ratio_)
# Out:
# [0.98788879]

# %%
df["cattle_pca"] = pca.transform(df.drop(columns=["YEAR","LOCATION","CATTLE_BREED_TYPE",
                    "CATTLE_GENDER","CATTLE_AGE_30_36",
                    "CATTLE_AGE_36_PLUS"]))

# %%
df = df.drop(columns=["CATTLE_AGE_0_6","CATTLE_AGE_6_6","CATTLE_AGE_6_12",
                   "CATTLE_AGE_12_18","CATTLE_AGE_18_24","CATTLE_AGE_24_30"])

# %%
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head(3)
# Out:
#    YEAR LOCATION CATTLE_BREED_TYPE CATTLE_GENDER  CATTLE_AGE_30_36  \
# 0  2014    Boyne              BEEF             C              3929
# 1  2020  Doonbeg              BEEF             C               312
# 2  2019     Ilen              BEEF             C               473
#
#    CATTLE_AGE_36_PLUS   cattle_pca
# 0               57144 -6507.626832
# 1                5863 -6667.995660
# 2                6794 -6664.552811

# %%
df.groupby("YEAR").mean()["cattle_pca"].plot()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
sns.kdeplot(data=df, x="cattle_pca", hue="LOCATION")
# Out:
# <AxesSubplot:xlabel='cattle_pca', ylabel='Density'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, x="LOCATION", y="cattle_pca")
# Out:
# <AxesSubplot:xlabel='LOCATION', ylabel='cattle_pca'>

# %%
sns.kdeplot(data=df, x="cattle_pca", hue="CATTLE_BREED_TYPE")
# Out:
# <AxesSubplot:xlabel='cattle_pca', ylabel='Density'>

# %%
sns.boxplot(data=df, x="CATTLE_BREED_TYPE", y="cattle_pca")
# Out:
# <AxesSubplot:xlabel='CATTLE_BREED_TYPE', ylabel='cattle_pca'>

# %%
sns.boxplot(data=df, x="CATTLE_BREED_TYPE", y="cattle_pca", showfliers=False)
# Out:
# <AxesSubplot:xlabel='CATTLE_BREED_TYPE', ylabel='cattle_pca'>

# %%
sns.kdeplot(data=df, x="cattle_pca", hue="CATTLE_GENDER")
# Out:
# <AxesSubplot:xlabel='cattle_pca', ylabel='Density'>

# %%
sns.boxplot(data=df, x="CATTLE_GENDER", y="cattle_pca")
# Out:
# <AxesSubplot:xlabel='CATTLE_GENDER', ylabel='cattle_pca'>

# %%
sns.boxplot(data=df, x="CATTLE_GENDER", y="cattle_pca",showfliers=False)
# Out:
# <AxesSubplot:xlabel='CATTLE_GENDER', ylabel='cattle_pca'>

# %%
x_columns=["YEAR","CATTLE_BREED_TYPE","CATTLE_GENDER",
           "CATTLE_AGE_30_36","CATTLE_AGE_36_PLUS","cattle_pca"]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X = pd.get_dummies(df[x_columns])

# %%
X = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans
import numpy as np
from scipy.spatial.distance import cdist

# %%
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = list(range(1,10))
for k in K:
    # Building and fitting the model
    kmean_model = KMeans(n_clusters=k).fit(X)
    kmean_model.fit(X)
 
    distortions.append(sum(np.min(cdist(X, kmean_model.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmean_model.inertia_)
 
    mapping1[k] = sum(np.min(cdist(X, kmean_model.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmean_model.inertia_

# %%
plt.plot(K,distortions)

# %%
kmean_model = KMeans(n_clusters=6).fit(X)
kmean_model.fit(X)
# Out:
# KMeans(n_clusters=6)

# %%
df["cluster"] = kmean_model.predict(X)

# %%
sns.boxplot(data=df,x="cluster",y="CATTLE_AGE_30_36")
# Out:
# <AxesSubplot:xlabel='cluster', ylabel='CATTLE_AGE_30_36'>

# %%
sns.boxplot(data=df,x="cluster",y="CATTLE_AGE_36_PLUS")
# Out:
# <AxesSubplot:xlabel='cluster', ylabel='CATTLE_AGE_36_PLUS'>

# %%
sns.boxplot(data=df,x="cluster",y="cattle_pca")
# Out:
# <AxesSubplot:xlabel='cluster', ylabel='cattle_pca'>

# %%
df.columns
# Out:
# Index(['YEAR', 'LOCATION', 'CATTLE_BREED_TYPE', 'CATTLE_GENDER',
#        'CATTLE_AGE_30_36', 'CATTLE_AGE_36_PLUS', 'cattle_pca', 'cluster'],
#       dtype='object')

# %%
sns.catplot(data=df, x="CATTLE_GENDER", hue = "cluster",kind="count")

# %%
sns.catplot(data=df, x="CATTLE_BREED_TYPE", hue = "cluster",kind="count")

# %%
sns.boxplot(data=df,x="cluster",y="YEAR")
# Out:
# <AxesSubplot:xlabel='cluster', ylabel='YEAR'>

# %%
for k in range(6):
    print(df[df["cluster"]==k].describe(include="all").drop(columns=["cluster"]))
# Out:
#                YEAR LOCATION CATTLE_BREED_TYPE CATTLE_GENDER  \
# count    588.000000      588               588           588
# unique          NaN       12                 1             1
# top             NaN     Nore              BEEF             M
# freq            NaN       49               588           588
# mean    2017.000000      NaN               NaN           NaN
# std        2.001703      NaN               NaN           NaN
# min     2014.000000      NaN               NaN           NaN
# 25%     2015.000000      NaN               NaN           NaN
# 50%     2017.000000      NaN               NaN           NaN
# 75%     2019.000000      NaN               NaN           NaN
# max     2020.000000      NaN               NaN           NaN
#
#         CATTLE_AGE_30_36  CATTLE_AGE_36_PLUS    cattle_pca
# count         588.000000          588.000000    588.000000
# unique               NaN                 NaN           NaN
# top                  NaN                 NaN           NaN
# freq                 NaN                 NaN           NaN
# mean         1318.477891          757.013605   7109.425865
# std          2161.904080         1007.706127  20426.995183
# min             2.000000           12.000000  -6541.338116
# 25%            15.750000           37.000000  -6450.943640
# 50%           154.000000          185.500000  -4631.640089
# 75%          1568.500000         1283.000000  14238.126166
# max          8822.000000         3588.000000  59876.663159
#                YEAR LOCATION CATTLE_BREED_TYPE CATTLE_GENDER  \
# count    575.000000      575               575           575
# unique          NaN       12                 1             1
# top             NaN   Dargle             DAIRY             F
# freq            NaN       49               575           575
# mean    2017.015652      NaN               NaN           NaN
# std        2.003855      NaN               NaN           NaN
# min     2014.000000      NaN               NaN           NaN
# 25%     2015.000000      NaN               NaN           NaN
# 50%     2017.000000      NaN               NaN           NaN
# 75%     2019.000000      NaN               NaN           NaN
# max     2020.000000      NaN               NaN           NaN
#
#         CATTLE_AGE_30_36  CATTLE_AGE_36_PLUS    cattle_pca
# count         575.000000          575.000000    575.000000
# unique               NaN                 NaN           NaN
# top                  NaN                 NaN           NaN
# freq                 NaN                 NaN           NaN
# mean          793.926957          215.034783    655.830051
# std          1246.836404          329.767819  12340.131960
# min             0.000000            0.000000  -6678.244221
# 25%             5.500000            1.000000  -6516.993466
# 50%           263.000000           51.000000  -4808.005425
# 75%           775.500000          237.500000    719.025984
# max          5353.000000         1371.000000  39481.654116
#                YEAR LOCATION CATTLE_BREED_TYPE CATTLE_GENDER  \
# count    576.000000      576               576           576
# unique          NaN       12                 1             1
# top             NaN   Dargle             DAIRY             M
# freq            NaN       49               576           576
# mean    2017.008681      NaN               NaN           NaN
# std        2.013414      NaN               NaN           NaN
# min     2014.000000      NaN               NaN           NaN
# 25%     2015.000000      NaN               NaN           NaN
# 50%     2017.000000      NaN               NaN           NaN
# 75%     2019.000000      NaN               NaN           NaN
# max     2020.000000      NaN               NaN           NaN
#
#         CATTLE_AGE_30_36  CATTLE_AGE_36_PLUS    cattle_pca
# count         576.000000          576.000000    576.000000
# unique               NaN                 NaN           NaN
# top                  NaN                 NaN           NaN
# freq                 NaN                 NaN           NaN
# mean          314.909722           72.133681  -1695.339384
# std           588.709340          120.873579  10295.533678
# min             0.000000            0.000000  -6677.728785
# 25%             2.000000            0.000000  -6638.096680
# 50%            59.000000           16.000000  -5704.837916
# 75%           214.000000           69.500000  -3844.802048
# max          2615.000000          520.000000  34290.586219
#                YEAR LOCATION CATTLE_BREED_TYPE CATTLE_GENDER  \
# count    588.000000      588               588           588
# unique          NaN       12                 1             1
# top             NaN    Boyne              BEEF             C
# freq            NaN       49               588           588
# mean    2017.000000      NaN               NaN           NaN
# std        2.001703      NaN               NaN           NaN
# min     2014.000000      NaN               NaN           NaN
# 25%     2015.000000      NaN               NaN           NaN
# 50%     2017.000000      NaN               NaN           NaN
# 75%     2019.000000      NaN               NaN           NaN
# max     2020.000000      NaN               NaN           NaN
#
#         CATTLE_AGE_30_36  CATTLE_AGE_36_PLUS   cattle_pca
# count         588.000000          588.000000   588.000000
# unique               NaN                 NaN          NaN
# top                  NaN                 NaN          NaN
# freq                 NaN                 NaN          NaN
# mean         1323.294218        16253.260204 -6629.028772
# std          1754.312481        20574.481507    68.367760
# min            13.000000          430.000000 -6678.394344
# 25%            62.750000         1033.250000 -6676.312608
# 50%           286.000000         3834.500000 -6668.606153
# 75%          2581.250000        33454.250000 -6598.351198
# max          5767.000000        57491.000000 -6436.852712
#                YEAR LOCATION CATTLE_BREED_TYPE CATTLE_GENDER  \
# count    588.000000      588               588           588
# unique          NaN       12                 1             1
# top             NaN    Boyne              BEEF             F
# freq            NaN       49               588           588
# mean    2017.000000      NaN               NaN           NaN
# std        2.001703      NaN               NaN           NaN
# min     2014.000000      NaN               NaN           NaN
# 25%     2015.000000      NaN               NaN           NaN
# 50%     2017.000000      NaN               NaN           NaN
# 75%     2019.000000      NaN               NaN           NaN
# max     2020.000000      NaN               NaN           NaN
#
#         CATTLE_AGE_30_36  CATTLE_AGE_36_PLUS    cattle_pca
# count         588.000000          588.000000    588.000000
# unique               NaN                 NaN           NaN
# top                  NaN                 NaN           NaN
# freq                 NaN                 NaN           NaN
# mean         1623.763605          405.069728   7185.771402
# std          2239.813934          523.563345  19691.109288
# min            24.000000            4.000000  -6463.636238
# 25%            65.000000           22.000000  -6331.587868
# 50%           332.000000           89.000000  -4400.710397
# 75%          3457.000000          844.500000  17373.972481
# max          8231.000000         1764.000000  54027.629063
#                YEAR LOCATION CATTLE_BREED_TYPE CATTLE_GENDER  \
# count    588.000000      588               588           588
# unique          NaN       12                 1             1
# top             NaN   Dargle             DAIRY             C
# freq            NaN       49               588           588
# mean    2017.000000      NaN               NaN           NaN
# std        2.001703      NaN               NaN           NaN
# min     2014.000000      NaN               NaN           NaN
# 25%     2015.000000      NaN               NaN           NaN
# 50%     2017.000000      NaN               NaN           NaN
# 75%     2019.000000      NaN               NaN           NaN
# max     2020.000000      NaN               NaN           NaN
#
#         CATTLE_AGE_30_36  CATTLE_AGE_36_PLUS   cattle_pca
# count         588.000000          588.000000   588.000000
# unique               NaN                 NaN          NaN
# top                  NaN                 NaN          NaN
# freq                 NaN                 NaN          NaN
# mean         3516.222789        17059.462585 -6646.758280
# std          6128.436240        27569.066267    54.574753
# min             0.000000            1.000000 -6678.394344
# 25%            24.000000          104.000000 -6678.394344
# 50%           679.500000         3380.500000 -6674.175805
# 75%          3773.500000        19097.250000 -6647.013097
# max         24984.000000       106374.000000 -6471.150109

# %%
df = df.groupby(["YEAR","CATTLE_BREED_TYPE"]).sum().reset_index()

# %%
df = df[["YEAR","CATTLE_BREED_TYPE","cattle_pca"]].pivot_table(values="cattle_pca",index="YEAR",
                                                          columns="CATTLE_BREED_TYPE")

# %%
df.columns.name = ""

# %%
df = df.reset_index()

# %%
sns.lineplot(data=df, x="YEAR", y="BEEF")
plt.show()
sns.lineplot(data=df, x="YEAR", y="DAIRY")
plt.show()

# %%
df.to_csv("cattle_year.csv")
